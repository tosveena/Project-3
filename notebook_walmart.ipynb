# %%
# Import dependencies
import pandas as pd
import numpy as np
import requests
from splinter import Browser
from bs4 import BeautifulSoup
import csv

# %%
# Generate array of the number of pages desired for scraping
pages = np.arange(1,41,1)

# %%
# Create base url
url = 'https://www.walmart.com/browse/household-essentials/cleaning-supplies/1115193_1071966?page='

# %%
# Create HTML files of each products result page
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

for page in pages:
    query_url = url + str(page)
    browser.visit(query_url)
    # HTML object
    html = browser.html
    # Parse HTML with BeautifulSoup
    soup = BeautifulSoup(html, 'html.parser')
    # Save to HTML file
    filepath = f'html_archive/html{page}.txt'
    with open(filepath, mode="w",  encoding="utf8") as code:
        code.write(str(soup.prettify()))

# %%
# Create list container to store individual product hyperlinks
href_list = []

# Iterate through each text file (results webpage) and extract unique individual product hyperlinks
for page in pages:
    filepath=f'html_archive/html{page}.txt'
    with open(filepath, 'r', encoding='utf-8') as text:
        lines=text.read()
        soup = BeautifulSoup(lines, 'html.parser')
        for div in soup.find_all('div', attrs={'class': 'search-result-product-title gridview'}):
            href = f"http://walmart.com{div.find('a')['href']}"
            if href not in href_list:
                href_list.append(href)

# Store and print the number of hyperlinks in href_list
href_count = len(href_list)
print(f'Number of products scraped: {href_count}')
# Out:
# Number of products scraped: 1014

# %%
# Create list containers to store scraped data
name_list = []
upc_list = []
currency_list = []
price_dollars_list = []
price_decimal_list = []
price_cents_list = []
customer_rating_list = []
number_of_reviews_list = []
seller_list = []
ingredients_list = []

# %%
# Create function to pull data
def append_to_list(tag, element, element_value, container):
    try:
        value = soup.find(tag, attrs={element:element_value}).text
        container.append(value)
    except(AttributeError):
        container.append('')

# Track processing record number
counter = 0        

# Iterate through each product hyperlink within hyperlinks list
for href in href_list:
    counter += 1
    response = requests.get(href)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Name
    append_to_list('h1', 'itemprop', 'name', name_list)
    
    # UPC (contained within soup object's script)
    try:
        soup_script = soup.find('script', attrs={'id':'item', 'type':'application/json'}).text
        clean_soup_script = soup_script.replace('null', 'None').replace('false', 'False').replace('true', 'True')
        script_dict = eval(clean_soup_script)
        upc_list.append(script_dict['item']['product']['buyBox']['products'][0]['upc'])
    except(AttributeError, KeyError):
        upc_list.append('')
        
    # Currency
    append_to_list('span', 'class', 'price-currency', currency_list)
    
    # Price
    append_to_list('span', 'class', 'price-characteristic', price_dollars_list)
    append_to_list('span', 'class', 'price-mark', price_decimal_list)    
    append_to_list('span', 'class', 'price-mantissa', price_cents_list)
    
    # Customer rating
    append_to_list('span', 'class', 'seo-avg-rating', customer_rating_list)
    
    # Number of reviews
    append_to_list('span', 'class', 'seo-review-count', number_of_reviews_list)
    
    # Seller
    append_to_list('a', 'class', 'seller-name', seller_list)
    
    # Ingredients
    try:
        soup_ingredients = soup.find('p', class_='Ingredients')
        ingredients_list.append(soup_ingredients.find('span', class_='aboutModuleText').text)
    except(AttributeError):
        ingredients_list.append('')
        
    # Print processing status
    print(f'Processing record {counter} of {href_count}.')
# Out:
# Processing record 1 of 1014.
# Processing record 2 of 1014.
# Processing record 3 of 1014.
# Processing record 4 of 1014.
# Processing record 5 of 1014.
# Processing record 6 of 1014.
# Processing record 7 of 1014.
# Processing record 8 of 1014.
# Processing record 9 of 1014.
# Processing record 10 of 1014.
# Processing record 11 of 1014.
# Processing record 12 of 1014.
# Processing record 13 of 1014.
# Processing record 14 of 1014.
# Processing record 15 of 1014.
# Processing record 16 of 1014.
# Processing record 17 of 1014.
# Processing record 18 of 1014.
# Processing record 19 of 1014.
# Processing record 20 of 1014.
# Processing record 21 of 1014.
# Processing record 22 of 1014.
# Processing record 23 of 1014.
# Processing record 24 of 1014.
# Processing record 25 of 1014.
# Processing record 26 of 1014.
# Processing record 27 of 1014.
# Processing record 28 of 1014.
# Processing record 29 of 1014.
# Processing record 30 of 1014.
# Processing record 31 of 1014.
# Processing record 32 of 1014.
# Processing record 33 of 1014.
# Processing record 34 of 1014.
# Processing record 35 of 1014.
# Processing record 36 of 1014.
# Processing record 37 of 1014.
# Processing record 38 of 1014.
# Processing record 39 of 1014.
# Processing record 40 of 1014.
# Processing record 41 of 1014.
# Processing record 42 of 1014.
# Processing record 43 of 1014.
# Processing record 44 of 1014.
# Processing record 45 of 1014.
# Processing record 46 of 1014.
# Processing record 47 of 1014.
# Processing record 48 of 1014.
# Processing record 49 of 1014.
# Processing record 50 of 1014.
# Processing record 51 of 1014.
# Processing record 52 of 1014.
# Processing record 53 of 1014.
# Processing record 54 of 1014.
# Processing record 55 of 1014.
# Processing record 56 of 1014.
# Processing record 57 of 1014.
# Processing record 58 of 1014.
# Processing record 59 of 1014.
# Processing record 60 of 1014.
# Processing record 61 of 1014.
# Processing record 62 of 1014.
# Processing record 63 of 1014.
# Processing record 64 of 1014.
# Processing record 65 of 1014.
# Processing record 66 of 1014.
# Processing record 67 of 1014.
# Processing record 68 of 1014.
# Processing record 69 of 1014.
# Processing record 70 of 1014.
# Processing record 71 of 1014.
# Processing record 72 of 1014.
# Processing record 73 of 1014.
# Processing record 74 of 1014.
# Processing record 75 of 1014.
# Processing record 76 of 1014.
# Processing record 77 of 1014.
# Processing record 78 of 1014.
# Processing record 79 of 1014.
# Processing record 80 of 1014.
# Processing record 81 of 1014.
# Processing record 82 of 1014.
# Processing record 83 of 1014.
# Processing record 84 of 1014.
# Processing record 85 of 1014.
# Processing record 86 of 1014.
# Processing record 87 of 1014.
# Processing record 88 of 1014.
# Processing record 89 of 1014.
# Processing record 90 of 1014.
# Processing record 91 of 1014.
# Processing record 92 of 1014.
# Processing record 93 of 1014.
# Processing record 94 of 1014.
# Processing record 95 of 1014.
# Processing record 96 of 1014.
# Processing record 97 of 1014.
# Processing record 98 of 1014.
# Processing record 99 of 1014.
# Processing record 100 of 1014.
# Processing record 101 of 1014.
# Processing record 102 of 1014.
# Processing record 103 of 1014.
# Processing record 104 of 1014.
# Processing record 105 of 1014.
# Processing record 106 of 1014.
# Processing record 107 of 1014.
# Processing record 108 of 1014.
# Processing record 109 of 1014.
# Processing record 110 of 1014.
# Processing record 111 of 1014.
# Processing record 112 of 1014.
# Processing record 113 of 1014.
# Processing record 114 of 1014.
# Processing record 115 of 1014.
# Processing record 116 of 1014.
# Processing record 117 of 1014.
# Processing record 118 of 1014.
# Processing record 119 of 1014.
# Processing record 120 of 1014.
# Processing record 121 of 1014.
# Processing record 122 of 1014.
# Processing record 123 of 1014.
# Processing record 124 of 1014.
# Processing record 125 of 1014.
# Processing record 126 of 1014.
# Processing record 127 of 1014.
# Processing record 128 of 1014.
# Processing record 129 of 1014.
# Processing record 130 of 1014.
# Processing record 131 of 1014.
# Processing record 132 of 1014.
# Processing record 133 of 1014.
# Processing record 134 of 1014.
# Processing record 135 of 1014.
# Processing record 136 of 1014.
# Processing record 137 of 1014.
# Processing record 138 of 1014.
# Processing record 139 of 1014.
# Processing record 140 of 1014.
# Processing record 141 of 1014.
# Processing record 142 of 1014.
# Processing record 143 of 1014.
# Processing record 144 of 1014.
# Processing record 145 of 1014.
# Processing record 146 of 1014.
# Processing record 147 of 1014.
# Processing record 148 of 1014.
# Processing record 149 of 1014.
# Processing record 150 of 1014.
# Processing record 151 of 1014.
# Processing record 152 of 1014.
# Processing record 153 of 1014.
# Processing record 154 of 1014.
# Processing record 155 of 1014.
# Processing record 156 of 1014.
# Processing record 157 of 1014.
# Processing record 158 of 1014.
# Processing record 159 of 1014.
# Processing record 160 of 1014.
# Processing record 161 of 1014.
# Processing record 162 of 1014.
# Processing record 163 of 1014.
# Processing record 164 of 1014.
# Processing record 165 of 1014.
# Processing record 166 of 1014.
# Processing record 167 of 1014.
# Processing record 168 of 1014.
# Processing record 169 of 1014.
# Processing record 170 of 1014.
# Processing record 171 of 1014.
# Processing record 172 of 1014.
# Processing record 173 of 1014.
# Processing record 174 of 1014.
# Processing record 175 of 1014.
# Processing record 176 of 1014.
# Processing record 177 of 1014.
# Processing record 178 of 1014.
# Processing record 179 of 1014.
# Processing record 180 of 1014.
# Processing record 181 of 1014.
# Processing record 182 of 1014.
# Processing record 183 of 1014.
# Processing record 184 of 1014.
# Processing record 185 of 1014.
# Processing record 186 of 1014.
# Processing record 187 of 1014.
# Processing record 188 of 1014.
# Processing record 189 of 1014.
# Processing record 190 of 1014.
# Processing record 191 of 1014.
# Processing record 192 of 1014.
# Processing record 193 of 1014.
# Processing record 194 of 1014.
# Processing record 195 of 1014.
# Processing record 196 of 1014.
# Processing record 197 of 1014.
# Processing record 198 of 1014.
# Processing record 199 of 1014.
# Processing record 200 of 1014.
# Processing record 201 of 1014.
# Processing record 202 of 1014.
# Processing record 203 of 1014.
# Processing record 204 of 1014.
# Processing record 205 of 1014.
# Processing record 206 of 1014.
# Processing record 207 of 1014.
# Processing record 208 of 1014.
# Processing record 209 of 1014.
# Processing record 210 of 1014.
# Processing record 211 of 1014.
# Processing record 212 of 1014.
# Processing record 213 of 1014.
# Processing record 214 of 1014.
# Processing record 215 of 1014.
# Processing record 216 of 1014.
# Processing record 217 of 1014.
# Processing record 218 of 1014.
# Processing record 219 of 1014.
# Processing record 220 of 1014.
# Processing record 221 of 1014.
# Processing record 222 of 1014.
# Processing record 223 of 1014.
# Processing record 224 of 1014.
# Processing record 225 of 1014.
# Processing record 226 of 1014.
# Processing record 227 of 1014.
# Processing record 228 of 1014.
# Processing record 229 of 1014.
# Processing record 230 of 1014.
# Processing record 231 of 1014.
# Processing record 232 of 1014.
# Processing record 233 of 1014.
# Processing record 234 of 1014.
# Processing record 235 of 1014.
# Processing record 236 of 1014.
# Processing record 237 of 1014.
# Processing record 238 of 1014.
# Processing record 239 of 1014.
# Processing record 240 of 1014.
# Processing record 241 of 1014.
# Processing record 242 of 1014.
# Processing record 243 of 1014.
# Processing record 244 of 1014.
# Processing record 245 of 1014.
# Processing record 246 of 1014.
# Processing record 247 of 1014.
# Processing record 248 of 1014.
# Processing record 249 of 1014.
# Processing record 250 of 1014.
# Processing record 251 of 1014.
# Processing record 252 of 1014.
# Processing record 253 of 1014.
# Processing record 254 of 1014.
# Processing record 255 of 1014.
# Processing record 256 of 1014.
# Processing record 257 of 1014.
# Processing record 258 of 1014.
# Processing record 259 of 1014.
# Processing record 260 of 1014.
# Processing record 261 of 1014.
# Processing record 262 of 1014.
# Processing record 263 of 1014.
# Processing record 264 of 1014.
# Processing record 265 of 1014.
# Processing record 266 of 1014.
# Processing record 267 of 1014.
# Processing record 268 of 1014.
# Processing record 269 of 1014.
# Processing record 270 of 1014.
# Processing record 271 of 1014.
# Processing record 272 of 1014.
# Processing record 273 of 1014.
# Processing record 274 of 1014.
# Processing record 275 of 1014.
# Processing record 276 of 1014.
# Processing record 277 of 1014.
# Processing record 278 of 1014.
# Processing record 279 of 1014.
# Processing record 280 of 1014.
# Processing record 281 of 1014.
# Processing record 282 of 1014.
# Processing record 283 of 1014.
# Processing record 284 of 1014.
# Processing record 285 of 1014.
# Processing record 286 of 1014.
# Processing record 287 of 1014.
# Processing record 288 of 1014.
# Processing record 289 of 1014.
# Processing record 290 of 1014.
# Processing record 291 of 1014.
# Processing record 292 of 1014.
# Processing record 293 of 1014.
# Processing record 294 of 1014.
# Processing record 295 of 1014.
# Processing record 296 of 1014.
# Processing record 297 of 1014.
# Processing record 298 of 1014.
# Processing record 299 of 1014.
# Processing record 300 of 1014.
# Processing record 301 of 1014.
# Processing record 302 of 1014.
# Processing record 303 of 1014.
# Processing record 304 of 1014.
# Processing record 305 of 1014.
# Processing record 306 of 1014.
# Processing record 307 of 1014.
# Processing record 308 of 1014.
# Processing record 309 of 1014.
# Processing record 310 of 1014.
# Processing record 311 of 1014.
# Processing record 312 of 1014.
# Processing record 313 of 1014.
# Processing record 314 of 1014.
# Processing record 315 of 1014.
# Processing record 316 of 1014.
# Processing record 317 of 1014.
# Processing record 318 of 1014.
# Processing record 319 of 1014.
# Processing record 320 of 1014.
# Processing record 321 of 1014.
# Processing record 322 of 1014.
# Processing record 323 of 1014.
# Processing record 324 of 1014.
# Processing record 325 of 1014.
# Processing record 326 of 1014.
# Processing record 327 of 1014.
# Processing record 328 of 1014.
# Processing record 329 of 1014.
# Processing record 330 of 1014.
# Processing record 331 of 1014.
# Processing record 332 of 1014.
# Processing record 333 of 1014.
# Processing record 334 of 1014.
# Processing record 335 of 1014.
# Processing record 336 of 1014.
# Processing record 337 of 1014.
# Processing record 338 of 1014.
# Processing record 339 of 1014.
# Processing record 340 of 1014.
# Processing record 341 of 1014.
# Processing record 342 of 1014.
# Processing record 343 of 1014.
# Processing record 344 of 1014.
# Processing record 345 of 1014.
# Processing record 346 of 1014.
# Processing record 347 of 1014.
# Processing record 348 of 1014.
# Processing record 349 of 1014.
# Processing record 350 of 1014.
# Processing record 351 of 1014.
# Processing record 352 of 1014.
# Processing record 353 of 1014.
# Processing record 354 of 1014.
# Processing record 355 of 1014.
# Processing record 356 of 1014.
# Processing record 357 of 1014.
# Processing record 358 of 1014.
# Processing record 359 of 1014.
# Processing record 360 of 1014.
# Processing record 361 of 1014.
# Processing record 362 of 1014.
# Processing record 363 of 1014.
# Processing record 364 of 1014.
# Processing record 365 of 1014.
# Processing record 366 of 1014.
# Processing record 367 of 1014.
# Processing record 368 of 1014.
# Processing record 369 of 1014.
# Processing record 370 of 1014.
# Processing record 371 of 1014.
# Processing record 372 of 1014.
# Processing record 373 of 1014.
# Processing record 374 of 1014.
# Processing record 375 of 1014.
# Processing record 376 of 1014.
# Processing record 377 of 1014.
# Processing record 378 of 1014.
# Processing record 379 of 1014.
# Processing record 380 of 1014.
# Processing record 381 of 1014.
# Processing record 382 of 1014.
# Processing record 383 of 1014.
# Processing record 384 of 1014.
# Processing record 385 of 1014.
# Processing record 386 of 1014.
# Processing record 387 of 1014.
# Processing record 388 of 1014.
# Processing record 389 of 1014.
# Processing record 390 of 1014.
# Processing record 391 of 1014.
# Processing record 392 of 1014.
# Processing record 393 of 1014.
# Processing record 394 of 1014.
# Processing record 395 of 1014.
# Processing record 396 of 1014.
# Processing record 397 of 1014.
# Processing record 398 of 1014.
# Processing record 399 of 1014.
# Processing record 400 of 1014.
# Processing record 401 of 1014.
# Processing record 402 of 1014.
# Processing record 403 of 1014.
# Processing record 404 of 1014.
# Processing record 405 of 1014.
# Processing record 406 of 1014.
# Processing record 407 of 1014.
# Processing record 408 of 1014.
# Processing record 409 of 1014.
# Processing record 410 of 1014.
# Processing record 411 of 1014.
# Processing record 412 of 1014.
# Processing record 413 of 1014.
# Processing record 414 of 1014.
# Processing record 415 of 1014.
# Processing record 416 of 1014.
# Processing record 417 of 1014.
# Processing record 418 of 1014.
# Processing record 419 of 1014.
# Processing record 420 of 1014.
# Processing record 421 of 1014.
# Processing record 422 of 1014.
# Processing record 423 of 1014.
# Processing record 424 of 1014.
# Processing record 425 of 1014.
# Processing record 426 of 1014.
# Processing record 427 of 1014.
# Processing record 428 of 1014.
# Processing record 429 of 1014.
# Processing record 430 of 1014.
# Processing record 431 of 1014.
# Processing record 432 of 1014.
# Processing record 433 of 1014.
# Processing record 434 of 1014.
# Processing record 435 of 1014.
# Processing record 436 of 1014.
# Processing record 437 of 1014.
# Processing record 438 of 1014.
# Processing record 439 of 1014.
# Processing record 440 of 1014.
# Processing record 441 of 1014.
# Processing record 442 of 1014.
# Processing record 443 of 1014.
# Processing record 444 of 1014.
# Processing record 445 of 1014.
# Processing record 446 of 1014.
# Processing record 447 of 1014.
# Processing record 448 of 1014.
# Processing record 449 of 1014.
# Processing record 450 of 1014.
# Processing record 451 of 1014.
# Processing record 452 of 1014.
# Processing record 453 of 1014.
# Processing record 454 of 1014.
# Processing record 455 of 1014.
# Processing record 456 of 1014.
# Processing record 457 of 1014.
# Processing record 458 of 1014.
# Processing record 459 of 1014.
# Processing record 460 of 1014.
# Processing record 461 of 1014.
# Processing record 462 of 1014.
# Processing record 463 of 1014.
# Processing record 464 of 1014.
# Processing record 465 of 1014.
# Processing record 466 of 1014.
# Processing record 467 of 1014.
# Processing record 468 of 1014.
# Processing record 469 of 1014.
# Processing record 470 of 1014.
# Processing record 471 of 1014.
# Processing record 472 of 1014.
# Processing record 473 of 1014.
# Processing record 474 of 1014.
# Processing record 475 of 1014.
# Processing record 476 of 1014.
# Processing record 477 of 1014.
# Processing record 478 of 1014.
# Processing record 479 of 1014.
# Processing record 480 of 1014.
# Processing record 481 of 1014.
# Processing record 482 of 1014.
# Processing record 483 of 1014.
# Processing record 484 of 1014.
# Processing record 485 of 1014.
# Processing record 486 of 1014.
# Processing record 487 of 1014.
# Processing record 488 of 1014.
# Processing record 489 of 1014.
# Processing record 490 of 1014.
# Processing record 491 of 1014.
# Processing record 492 of 1014.
# Processing record 493 of 1014.
# Processing record 494 of 1014.
# Processing record 495 of 1014.
# Processing record 496 of 1014.
# Processing record 497 of 1014.
# Processing record 498 of 1014.
# Processing record 499 of 1014.
# Processing record 500 of 1014.
# Processing record 501 of 1014.
# Processing record 502 of 1014.
# Processing record 503 of 1014.
# Processing record 504 of 1014.
# Processing record 505 of 1014.
# Processing record 506 of 1014.
# Processing record 507 of 1014.
# Processing record 508 of 1014.
# Processing record 509 of 1014.
# Processing record 510 of 1014.
# Processing record 511 of 1014.
# Processing record 512 of 1014.
# Processing record 513 of 1014.
# Processing record 514 of 1014.
# Processing record 515 of 1014.
# Processing record 516 of 1014.
# Processing record 517 of 1014.
# Processing record 518 of 1014.
# Processing record 519 of 1014.
# Processing record 520 of 1014.
# Processing record 521 of 1014.
# Processing record 522 of 1014.
# Processing record 523 of 1014.
# Processing record 524 of 1014.
# Processing record 525 of 1014.
# Processing record 526 of 1014.
# Processing record 527 of 1014.
# Processing record 528 of 1014.
# Processing record 529 of 1014.
# Processing record 530 of 1014.
# Processing record 531 of 1014.
# Processing record 532 of 1014.
# Processing record 533 of 1014.
# Processing record 534 of 1014.
# Processing record 535 of 1014.
# Processing record 536 of 1014.
# Processing record 537 of 1014.
# Processing record 538 of 1014.
# Processing record 539 of 1014.
# Processing record 540 of 1014.
# Processing record 541 of 1014.
# Processing record 542 of 1014.
# Processing record 543 of 1014.
# Processing record 544 of 1014.
# Processing record 545 of 1014.
# Processing record 546 of 1014.
# Processing record 547 of 1014.
# Processing record 548 of 1014.
# Processing record 549 of 1014.
# Processing record 550 of 1014.
# Processing record 551 of 1014.
# Processing record 552 of 1014.
# Processing record 553 of 1014.
# Processing record 554 of 1014.
# Processing record 555 of 1014.
# Processing record 556 of 1014.
# Processing record 557 of 1014.
# Processing record 558 of 1014.
# Processing record 559 of 1014.
# Processing record 560 of 1014.
# Processing record 561 of 1014.
# Processing record 562 of 1014.
# Processing record 563 of 1014.
# Processing record 564 of 1014.
# Processing record 565 of 1014.
# Processing record 566 of 1014.
# Processing record 567 of 1014.
# Processing record 568 of 1014.
# Processing record 569 of 1014.
# Processing record 570 of 1014.
# Processing record 571 of 1014.
# Processing record 572 of 1014.
# Processing record 573 of 1014.
# Processing record 574 of 1014.
# Processing record 575 of 1014.
# Processing record 576 of 1014.
# Processing record 577 of 1014.
# Processing record 578 of 1014.
# Processing record 579 of 1014.
# Processing record 580 of 1014.
# Processing record 581 of 1014.
# Processing record 582 of 1014.
# Processing record 583 of 1014.
# Processing record 584 of 1014.
# Processing record 585 of 1014.
# Processing record 586 of 1014.
# Processing record 587 of 1014.
# Processing record 588 of 1014.
# Processing record 589 of 1014.
# Processing record 590 of 1014.
# Processing record 591 of 1014.
# Processing record 592 of 1014.
# Processing record 593 of 1014.
# Processing record 594 of 1014.
# Processing record 595 of 1014.
# Processing record 596 of 1014.
# Processing record 597 of 1014.
# Processing record 598 of 1014.
# Processing record 599 of 1014.
# Processing record 600 of 1014.
# Processing record 601 of 1014.
# Processing record 602 of 1014.
# Processing record 603 of 1014.
# Processing record 604 of 1014.
# Processing record 605 of 1014.
# Processing record 606 of 1014.
# Processing record 607 of 1014.
# Processing record 608 of 1014.
# Processing record 609 of 1014.
# Processing record 610 of 1014.
# Processing record 611 of 1014.
# Processing record 612 of 1014.
# Processing record 613 of 1014.
# Processing record 614 of 1014.
# Processing record 615 of 1014.
# Processing record 616 of 1014.
# Processing record 617 of 1014.
# Processing record 618 of 1014.
# Processing record 619 of 1014.
# Processing record 620 of 1014.
# Processing record 621 of 1014.
# Processing record 622 of 1014.
# Processing record 623 of 1014.
# Processing record 624 of 1014.
# Processing record 625 of 1014.
# Processing record 626 of 1014.
# Processing record 627 of 1014.
# Processing record 628 of 1014.
# Processing record 629 of 1014.
# Processing record 630 of 1014.
# Processing record 631 of 1014.
# Processing record 632 of 1014.
# Processing record 633 of 1014.
# Processing record 634 of 1014.
# Processing record 635 of 1014.
# Processing record 636 of 1014.
# Processing record 637 of 1014.
# Processing record 638 of 1014.
# Processing record 639 of 1014.
# Processing record 640 of 1014.
# Processing record 641 of 1014.
# Processing record 642 of 1014.
# Processing record 643 of 1014.
# Processing record 644 of 1014.
# Processing record 645 of 1014.
# Processing record 646 of 1014.
# Processing record 647 of 1014.
# Processing record 648 of 1014.
# Processing record 649 of 1014.
# Processing record 650 of 1014.
# Processing record 651 of 1014.
# Processing record 652 of 1014.
# Processing record 653 of 1014.
# Processing record 654 of 1014.
# Processing record 655 of 1014.
# Processing record 656 of 1014.
# Processing record 657 of 1014.
# Processing record 658 of 1014.
# Processing record 659 of 1014.
# Processing record 660 of 1014.
# Processing record 661 of 1014.
# Processing record 662 of 1014.
# Processing record 663 of 1014.
# Processing record 664 of 1014.
# Processing record 665 of 1014.
# Processing record 666 of 1014.
# Processing record 667 of 1014.
# Processing record 668 of 1014.
# Processing record 669 of 1014.
# Processing record 670 of 1014.
# Processing record 671 of 1014.
# Processing record 672 of 1014.
# Processing record 673 of 1014.
# Processing record 674 of 1014.
# Processing record 675 of 1014.
# Processing record 676 of 1014.
# Processing record 677 of 1014.
# Processing record 678 of 1014.
# Processing record 679 of 1014.
# Processing record 680 of 1014.
# Processing record 681 of 1014.
# Processing record 682 of 1014.
# Processing record 683 of 1014.
# Processing record 684 of 1014.
# Processing record 685 of 1014.
# Processing record 686 of 1014.
# Processing record 687 of 1014.
# Processing record 688 of 1014.
# Processing record 689 of 1014.
# Processing record 690 of 1014.
# Processing record 691 of 1014.
# Processing record 692 of 1014.
# Processing record 693 of 1014.
# Processing record 694 of 1014.
# Processing record 695 of 1014.
# Processing record 696 of 1014.
# Processing record 697 of 1014.
# Processing record 698 of 1014.
# Processing record 699 of 1014.
# Processing record 700 of 1014.
# Processing record 701 of 1014.
# Processing record 702 of 1014.
# Processing record 703 of 1014.
# Processing record 704 of 1014.
# Processing record 705 of 1014.
# Processing record 706 of 1014.
# Processing record 707 of 1014.
# Processing record 708 of 1014.
# Processing record 709 of 1014.
# Processing record 710 of 1014.
# Processing record 711 of 1014.
# Processing record 712 of 1014.
# Processing record 713 of 1014.
# Processing record 714 of 1014.
# Processing record 715 of 1014.
# Processing record 716 of 1014.
# Processing record 717 of 1014.
# Processing record 718 of 1014.
# Processing record 719 of 1014.
# Processing record 720 of 1014.
# Processing record 721 of 1014.
# Processing record 722 of 1014.
# Processing record 723 of 1014.
# Processing record 724 of 1014.
# Processing record 725 of 1014.
# Processing record 726 of 1014.
# Processing record 727 of 1014.
# Processing record 728 of 1014.
# Processing record 729 of 1014.
# Processing record 730 of 1014.
# Processing record 731 of 1014.
# Processing record 732 of 1014.
# Processing record 733 of 1014.
# Processing record 734 of 1014.
# Processing record 735 of 1014.
# Processing record 736 of 1014.
# Processing record 737 of 1014.
# Processing record 738 of 1014.
# Processing record 739 of 1014.
# Processing record 740 of 1014.
# Processing record 741 of 1014.
# Processing record 742 of 1014.
# Processing record 743 of 1014.
# Processing record 744 of 1014.
# Processing record 745 of 1014.
# Processing record 746 of 1014.
# Processing record 747 of 1014.
# Processing record 748 of 1014.
# Processing record 749 of 1014.
# Processing record 750 of 1014.
# Processing record 751 of 1014.
# Processing record 752 of 1014.
# Processing record 753 of 1014.
# Processing record 754 of 1014.
# Processing record 755 of 1014.
# Processing record 756 of 1014.
# Processing record 757 of 1014.
# Processing record 758 of 1014.
# Processing record 759 of 1014.
# Processing record 760 of 1014.
# Processing record 761 of 1014.
# Processing record 762 of 1014.
# Processing record 763 of 1014.
# Processing record 764 of 1014.
# Processing record 765 of 1014.
# Processing record 766 of 1014.
# Processing record 767 of 1014.
# Processing record 768 of 1014.
# Processing record 769 of 1014.
# Processing record 770 of 1014.
# Processing record 771 of 1014.
# Processing record 772 of 1014.
# Processing record 773 of 1014.
# Processing record 774 of 1014.
# Processing record 775 of 1014.
# Processing record 776 of 1014.
# Processing record 777 of 1014.
# Processing record 778 of 1014.
# Processing record 779 of 1014.
# Processing record 780 of 1014.
# Processing record 781 of 1014.
# Processing record 782 of 1014.
# Processing record 783 of 1014.
# Processing record 784 of 1014.
# Processing record 785 of 1014.
# Processing record 786 of 1014.
# Processing record 787 of 1014.
# Processing record 788 of 1014.
# Processing record 789 of 1014.
# Processing record 790 of 1014.
# Processing record 791 of 1014.
# Processing record 792 of 1014.
# Processing record 793 of 1014.
# Processing record 794 of 1014.
# Processing record 795 of 1014.
# Processing record 796 of 1014.
# Processing record 797 of 1014.
# Processing record 798 of 1014.
# Processing record 799 of 1014.
# Processing record 800 of 1014.
# Processing record 801 of 1014.
# Processing record 802 of 1014.
# Processing record 803 of 1014.
# Processing record 804 of 1014.
# Processing record 805 of 1014.
# Processing record 806 of 1014.
# Processing record 807 of 1014.
# Processing record 808 of 1014.
# Processing record 809 of 1014.
# Processing record 810 of 1014.
# Processing record 811 of 1014.
# Processing record 812 of 1014.
# Processing record 813 of 1014.
# Processing record 814 of 1014.
# Processing record 815 of 1014.
# Processing record 816 of 1014.
# Processing record 817 of 1014.
# Processing record 818 of 1014.
# Processing record 819 of 1014.
# Processing record 820 of 1014.
# Processing record 821 of 1014.
# Processing record 822 of 1014.
# Processing record 823 of 1014.
# Processing record 824 of 1014.
# Processing record 825 of 1014.
# Processing record 826 of 1014.
# Processing record 827 of 1014.
# Processing record 828 of 1014.
# Processing record 829 of 1014.
# Processing record 830 of 1014.
# Processing record 831 of 1014.
# Processing record 832 of 1014.
# Processing record 833 of 1014.
# Processing record 834 of 1014.
# Processing record 835 of 1014.
# Processing record 836 of 1014.
# Processing record 837 of 1014.
# Processing record 838 of 1014.
# Processing record 839 of 1014.
# Processing record 840 of 1014.
# Processing record 841 of 1014.
# Processing record 842 of 1014.
# Processing record 843 of 1014.
# Processing record 844 of 1014.
# Processing record 845 of 1014.
# Processing record 846 of 1014.
# Processing record 847 of 1014.
# Processing record 848 of 1014.
# Processing record 849 of 1014.
# Processing record 850 of 1014.
# Processing record 851 of 1014.
# Processing record 852 of 1014.
# Processing record 853 of 1014.
# Processing record 854 of 1014.
# Processing record 855 of 1014.
# Processing record 856 of 1014.
# Processing record 857 of 1014.
# Processing record 858 of 1014.
# Processing record 859 of 1014.
# Processing record 860 of 1014.
# Processing record 861 of 1014.
# Processing record 862 of 1014.
# Processing record 863 of 1014.
# Processing record 864 of 1014.
# Processing record 865 of 1014.
# Processing record 866 of 1014.
# Processing record 867 of 1014.
# Processing record 868 of 1014.
# Processing record 869 of 1014.
# Processing record 870 of 1014.
# Processing record 871 of 1014.
# Processing record 872 of 1014.
# Processing record 873 of 1014.
# Processing record 874 of 1014.
# Processing record 875 of 1014.
# Processing record 876 of 1014.
# Processing record 877 of 1014.
# Processing record 878 of 1014.
# Processing record 879 of 1014.
# Processing record 880 of 1014.
# Processing record 881 of 1014.
# Processing record 882 of 1014.
# Processing record 883 of 1014.
# Processing record 884 of 1014.
# Processing record 885 of 1014.
# Processing record 886 of 1014.
# Processing record 887 of 1014.
# Processing record 888 of 1014.
# Processing record 889 of 1014.
# Processing record 890 of 1014.
# Processing record 891 of 1014.
# Processing record 892 of 1014.
# Processing record 893 of 1014.
# Processing record 894 of 1014.
# Processing record 895 of 1014.
# Processing record 896 of 1014.
# Processing record 897 of 1014.
# Processing record 898 of 1014.
# Processing record 899 of 1014.
# Processing record 900 of 1014.
# Processing record 901 of 1014.
# Processing record 902 of 1014.
# Processing record 903 of 1014.
# Processing record 904 of 1014.
# Processing record 905 of 1014.
# Processing record 906 of 1014.
# Processing record 907 of 1014.
# Processing record 908 of 1014.
# Processing record 909 of 1014.
# Processing record 910 of 1014.
# Processing record 911 of 1014.
# Processing record 912 of 1014.
# Processing record 913 of 1014.
# Processing record 914 of 1014.
# Processing record 915 of 1014.
# Processing record 916 of 1014.
# Processing record 917 of 1014.
# Processing record 918 of 1014.
# Processing record 919 of 1014.
# Processing record 920 of 1014.
# Processing record 921 of 1014.
# Processing record 922 of 1014.
# Processing record 923 of 1014.
# Processing record 924 of 1014.
# Processing record 925 of 1014.
# Processing record 926 of 1014.
# Processing record 927 of 1014.
# Processing record 928 of 1014.
# Processing record 929 of 1014.
# Processing record 930 of 1014.
# Processing record 931 of 1014.
# Processing record 932 of 1014.
# Processing record 933 of 1014.
# Processing record 934 of 1014.
# Processing record 935 of 1014.
# Processing record 936 of 1014.
# Processing record 937 of 1014.
# Processing record 938 of 1014.
# Processing record 939 of 1014.
# Processing record 940 of 1014.
# Processing record 941 of 1014.
# Processing record 942 of 1014.
# Processing record 943 of 1014.
# Processing record 944 of 1014.
# Processing record 945 of 1014.
# Processing record 946 of 1014.
# Processing record 947 of 1014.
# Processing record 948 of 1014.
# Processing record 949 of 1014.
# Processing record 950 of 1014.
# Processing record 951 of 1014.
# Processing record 952 of 1014.
# Processing record 953 of 1014.
# Processing record 954 of 1014.
# Processing record 955 of 1014.
# Processing record 956 of 1014.
# Processing record 957 of 1014.
# Processing record 958 of 1014.
# Processing record 959 of 1014.
# Processing record 960 of 1014.
# Processing record 961 of 1014.
# Processing record 962 of 1014.
# Processing record 963 of 1014.
# Processing record 964 of 1014.
# Processing record 965 of 1014.
# Processing record 966 of 1014.
# Processing record 967 of 1014.
# Processing record 968 of 1014.
# Processing record 969 of 1014.
# Processing record 970 of 1014.
# Processing record 971 of 1014.
# Processing record 972 of 1014.
# Processing record 973 of 1014.
# Processing record 974 of 1014.
# Processing record 975 of 1014.
# Processing record 976 of 1014.
# Processing record 977 of 1014.
# Processing record 978 of 1014.
# Processing record 979 of 1014.
# Processing record 980 of 1014.
# Processing record 981 of 1014.
# Processing record 982 of 1014.
# Processing record 983 of 1014.
# Processing record 984 of 1014.
# Processing record 985 of 1014.
# Processing record 986 of 1014.
# Processing record 987 of 1014.
# Processing record 988 of 1014.
# Processing record 989 of 1014.
# Processing record 990 of 1014.
# Processing record 991 of 1014.
# Processing record 992 of 1014.
# Processing record 993 of 1014.
# Processing record 994 of 1014.
# Processing record 995 of 1014.
# Processing record 996 of 1014.
# Processing record 997 of 1014.
# Processing record 998 of 1014.
# Processing record 999 of 1014.
# Processing record 1000 of 1014.
# Processing record 1001 of 1014.
# Processing record 1002 of 1014.
# Processing record 1003 of 1014.
# Processing record 1004 of 1014.
# Processing record 1005 of 1014.
# Processing record 1006 of 1014.
# Processing record 1007 of 1014.
# Processing record 1008 of 1014.
# Processing record 1009 of 1014.
# Processing record 1010 of 1014.
# Processing record 1011 of 1014.
# Processing record 1012 of 1014.
# Processing record 1013 of 1014.
# Processing record 1014 of 1014.

# %%
# Convert data lists into a dictionary
product_dict = {
    'href': href_list,
    'name': name_list,
    'upc': upc_list,
    'currency': currency_list,
    'price_dollars': price_dollars_list,
    'price_decimal': price_decimal_list,
    'price_cents': price_cents_list,
    'customer_rating': customer_rating_list,
    'number_of_reviews': number_of_reviews_list,
    'seller': seller_list,
    'ingredients': ingredients_list
}

# %%
# Convert dictionary into a DataFrame
product_df = pd.DataFrame(product_dict)
product_df.head()
# Out:
#                                                 href  \
# 0  http://walmart.com/ip/Great-Value-Lavender-Sce...
# 1  http://walmart.com/ip/All-Purpose-Cleaning-Con...
# 2  http://walmart.com/ip/Mrs-Meyer-s-Clean-Day-Mu...
# 3  http://walmart.com/ip/Mrs-Meyer-s-Clean-Day-Mu...
# 4  http://walmart.com/ip/Fabuloso-All-Purpose-Cle...
#
#                                                 name           upc currency  \
# 0  Great Value Lavender Scent Multi-Purpose Clean...  078742105192        $
# 1  All-Purpose Cleaning Concentrate by The Laundress  859675001689        $
# 2  Mrs. Meyer's Clean Day Multi-Surface Concentra...  808124124400        $
# 3  Mrs. Meyer's Clean Day Multi-Surface Concentra...  808124175402        $
# 4  Fabuloso All Purpose Cleaner, Lavender - 128 f...  035000530585        $
#
#   price_dollars price_decimal price_cents customer_rating number_of_reviews  \
# 0             4             .          44             4.5                55
# 1             9             .          23               0                 0
# 2             8             .          88             4.8                34
# 3             7             .          82             4.9                18
# 4             5             .          78             4.8               431
#
#     seller                                        ingredients
# 0  Walmart  Water, 7732-18-5, Intentionally added non-frag...
# 1  Walmart  A concentrated blend of plant-derived anionic ...
# 2  Walmart  Water, Decyl Glucoside, Sodium Methyl 2-Sulfol...
# 3  Walmart  Water, Decyl Glucoside, Sodium Methyl 2-Sulfol...
# 4  Walmart

# %%
# Add column price which concats dollars, decimal, cents
product_df['price'] = product_df['price_dollars'] + product_df['price_decimal'] + product_df['price_cents']

# Drop source price columns
product_df.drop(['price_dollars', 'price_decimal', 'price_cents'], axis=1, inplace=True)

# Drops rows without product name
product_df = product_df.loc[product_df['name']!='', :]

# %%
# Organize columns
column_order = ['href', 'name', 'upc', 'currency', 'price', 'customer_rating', 'number_of_reviews', 'seller', 'ingredients']
clean_product_df = product_df[column_order]
clean_product_df.head()
# Out:
#                                                 href  \
# 0  http://walmart.com/ip/Great-Value-Lavender-Sce...
# 1  http://walmart.com/ip/All-Purpose-Cleaning-Con...
# 2  http://walmart.com/ip/Mrs-Meyer-s-Clean-Day-Mu...
# 3  http://walmart.com/ip/Mrs-Meyer-s-Clean-Day-Mu...
# 4  http://walmart.com/ip/Fabuloso-All-Purpose-Cle...
#
#                                                 name           upc currency  \
# 0  Great Value Lavender Scent Multi-Purpose Clean...  078742105192        $
# 1  All-Purpose Cleaning Concentrate by The Laundress  859675001689        $
# 2  Mrs. Meyer's Clean Day Multi-Surface Concentra...  808124124400        $
# 3  Mrs. Meyer's Clean Day Multi-Surface Concentra...  808124175402        $
# 4  Fabuloso All Purpose Cleaner, Lavender - 128 f...  035000530585        $
#
#   price customer_rating number_of_reviews   seller  \
# 0  4.44             4.5                55  Walmart
# 1  9.23               0                 0  Walmart
# 2  8.88             4.8                34  Walmart
# 3  7.82             4.9                18  Walmart
# 4  5.78             4.8               431  Walmart
#
#                                          ingredients
# 0  Water, 7732-18-5, Intentionally added non-frag...
# 1  A concentrated blend of plant-derived anionic ...
# 2  Water, Decyl Glucoside, Sodium Methyl 2-Sulfol...
# 3  Water, Decyl Glucoside, Sodium Methyl 2-Sulfol...
# 4

# %%
# Save to csv
clean_product_df.to_csv('data_walmart.csv', index=False, header=True)
